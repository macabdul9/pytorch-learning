# %%
import torch
import torchvision
import torch.nn as nn
import  torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchvision import datasets, transforms
from sklearn.datasets import load_digits, load_breast_cancer, load_boston, load_diabetes, load_wine, load_iris
import matplotlib.pyplot as plt

# %%
data = load_iris()

# %%
data.data.shape
# Out:
# (150, 4)

# %% [markdown]
# ## Load the Torch dataset

# %%
train = datasets.CIFAR10(root='./cifar', train=True, transform=transforms.ToTensor(), download=True)
test = datasets.CIFAR10(root='./cifar', train=False, transform=transforms.ToTensor(), download=True)
# Out:
# 0it [00:00, ?it/s]
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar/cifar-10-python.tar.gz
# 170500096it [00:06, 26822427.47it/s]
# Extracting ./cifar/cifar-10-python.tar.gz to ./cifar
# Files already downloaded and verified

# %%
print(len(train), len(test))
# Out:
# 50000 10000

# %%
train_dl = DataLoader(dataset=train, batch_size=256, shuffle=True)
test_dl = DataLoader(dataset=test, batch_size=512, shuffle=True)

# %% [markdown]
# ## Tensorboard Visualization

# %%
writer = SummaryWriter('runs/fashion_mnist_experiment_1')

# %%
def matplotlib_imshow(img, one_channel=False):
    plt.figure(figsize=(20, 20))
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg, cmap='gray')
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
# get some random training images
dataiter = iter(train_dl)
images, labels = dataiter.next()

# create grid of images
img_grid = torchvision.utils.make_grid(images, nrow=16)

# show images
matplotlib_imshow(img_grid, one_channel=True)

# write to tensorboard
writer.add_image('four_fashion_mnist_images', img_grid)

# %%
# !tensorboard --logdir=runs
# Out:
# TensorBoard 1.15.0 at http://3985ce42b1a9:6006/ (Press CTRL+C to quit)

# %%
import matplotlib

# %%
~matplotlib.colors.Colormap
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-926e55ef2924> in <module>()
# ----> 1 ~matplotlib.colors.Colormap
#
# TypeError: bad operand type for unary ~: 'type'

# %% [markdown]
# ## Create the  DNN Model

# %%
class DNN(nn.Moduel):
